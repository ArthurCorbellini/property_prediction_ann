# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from feature_engine.outliers import OutlierTrimmer

# %% [markdown]
# ---

# %% [markdown]
# # Utils

# %%
def show_data(data):
    data.info()
    print("\n\nThe columns are {}".format(data.columns))
    print("\n\nActual Data\n",data.head(2))

# outliers

def trimmer_skewed_iqr(variables, data_frame):
    return _build_trimmer(variables, 'iqr', 1.5, data_frame)

def trimmer_normal_gaussian(variables, data_frame):
    return _build_trimmer(variables, 'gaussian', 3, data_frame)

def trimmer_normal_quantile(variables, data_frame):
    return _build_trimmer(variables, 'quantiles', 0.05, data_frame)

def _build_trimmer(variables, capping_method, fold, data_frame):
    return OutlierTrimmer(
        variables=variables,
        capping_method=capping_method,
        tail='both',
        fold=fold
    ).fit_transform(data_frame)

def distinguish_variables(data):
    # Identificação dos tipos de variáveis, se são numéricas ou categóricas
    # - Numéricas são as int64 e float64;
    # - Categóricas são as object;
    numerical = [var for var in data.columns if data[var].dtype != "O"]
    categorical = [var for var in data.columns if data[var].dtype == "O"]
    # Identificação das variáveis discretas:
    # - Se tiver MENOS que 20 registros, é considerado uma variável DISCRETA;
    discrete = []
    for var in numerical:
        if len(data[var].unique()) < 20:
            discrete.append(var)
    # Identificação das variáveis contínuas:
    # - Se tiver MAIS que 20 registros, é considerado uma variável CONTÍNUA;
    continuous = [var for var in numerical if var not in discrete]

    return numerical, categorical, discrete, continuous

def visualize_discrete(df, discrete):
    plt.figure(figsize=(18, 6))
    position = 0
    for var in discrete:
        position += 1
        plt.subplot(1, 6, position)
        fig = (df.groupby(var)[var].count() / len(df)).plot.bar()
        fig.set_title(var)
        fig.set_ylabel('Percentage of observations per label')
        fig.axhline(y=0.05, color='red')

        position += 1
        plt.subplot(1, 6, position)
        fig = df.groupby(var)['rent'].median().plot()
        fig.set_ylabel('Median house Price per label')
        fig.set_title(var)
        fig.ticklabel_format(style='plain')

    plt.tight_layout()
    plt.show()

def visualize_continuous(df, continuous):
    plt.figure(figsize=(16, 8))
    position = 0
    for var in continuous:
        position += 1
        plt.subplot(2, 5, position)
        fig = df.boxplot(column=var)
        fig.set_title('')
        fig.set_ylabel(var)

        position += 1
        plt.subplot(2, 5, position)
        fig = df[var].hist(bins=20)
        fig.set_ylabel('Number of houses')
        fig.set_xlabel(var)

    plt.tight_layout()
    plt.show()

def visualize_boxplot(df):
    plt.rcParams["figure.figsize"] = [14.00, 14.00]
    plt.rcParams["figure.autolayout"] = True

    plt.rcParams['font.size'] = 10 
    plt.rcParams['axes.titlesize'] = 20

    f, axes = plt.subplots(2, 5)

    linha = 0
    coluna = 0
    for i in numerical:
        sns.boxplot(data = df, y=i, ax=axes[linha][coluna])
        coluna += 1
        if coluna == 5:
            linha += 1
            coluna = 0            

    plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Pré-processamento dos dados
#
# - city: Cidade
# - area: Área (m²)
# - rooms: Quartos
# - bathroom: Banheiros
# - parking spaces: Vagas de Estacionamento
# - floor: Andar
# - animal: Animal
# - furniture: Mobília
# - hoa (R$): Condomínio (R$)
# - rent amount (R$): Aluguel (R$)
# - property tax (R$): IPTU (R$)
# - fire insurance (R$): Seguro de Incêndio (R$)
# - total (R$): Total (R$)

# %% [markdown]
# ### Correções gerais

# %%
data = pd.read_csv("houses_to_rent_v2.csv")
data.rename({'parking spaces': 'parking_spaces', 
             'hoa (R$)': 'hoa', 
             'rent amount (R$)': 'rent', 
             'property tax (R$)': 'property_tax', 
             'fire insurance (R$)': 'fire_insurance', 
             'total (R$)': 'total'}, axis='columns', inplace=True)

df = data.drop(["total"], axis=1) # soma dos valores, não deve permanecer no conjunto

df.head()
# Out:
#            city  area  rooms  bathroom  parking_spaces floor     animal  \
# 0     São Paulo    70      2         1               1     7      acept
# 1     São Paulo   320      4         4               0    20      acept
# 2  Porto Alegre    80      1         1               1     6      acept
# 3  Porto Alegre    51      2         1               0     2      acept
# 4     São Paulo    25      1         1               0     1  not acept
#
#        furniture   hoa  rent  property_tax  fire_insurance
# 0      furnished  2065  3300           211              42
# 1  not furnished  1200  4960          1750              63
# 2  not furnished  1000  2800             0              41
# 3  not furnished   270  1112            22              17
# 4  not furnished     0   800            25              11

# %% [markdown]
# ### Tratamento dos valores nulos

# %%
df.info()
# Não há valores nulos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10692 entries, 0 to 10691
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   city            10692 non-null  object
#  1   area            10692 non-null  int64
#  2   rooms           10692 non-null  int64
#  3   bathroom        10692 non-null  int64
#  4   parking_spaces  10692 non-null  int64
#  5   floor           10692 non-null  object
#  6   animal          10692 non-null  object
#  7   furniture       10692 non-null  object
#  8   hoa             10692 non-null  int64
#  9   rent            10692 non-null  int64
#  10  property_tax    10692 non-null  int64
#  11  fire_insurance  10692 non-null  int64
# dtypes: int64(8), object(4)
# memory usage: 1002.5+ KB

# %% [markdown]
# ### Tratamento de duplicatas

# %%
df.duplicated().value_counts()
# Out:
# False    10334
# True       358
# Name: count, dtype: int64

# %%
df.drop_duplicates(inplace=True)
df.duplicated().value_counts()
# Out:
# False    10334
# Name: count, dtype: int64

# %% [markdown]
# ### Distinção das variáveis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10334 entries, 0 to 10691
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   city            10334 non-null  object
#  1   area            10334 non-null  int64
#  2   rooms           10334 non-null  int64
#  3   bathroom        10334 non-null  int64
#  4   parking_spaces  10334 non-null  int64
#  5   floor           10334 non-null  object
#  6   animal          10334 non-null  object
#  7   furniture       10334 non-null  object
#  8   hoa             10334 non-null  int64
#  9   rent            10334 non-null  int64
#  10  property_tax    10334 non-null  int64
#  11  fire_insurance  10334 non-null  int64
# dtypes: int64(8), object(4)
# memory usage: 1.0+ MB

# %%
numerical, categorical, discrete, continuous = distinguish_variables(df)

print("Categoricas: " + str(categorical))
print("Numericas: " + str(numerical))

print(" - Discretas: " + str(discrete))
print(" - Contínuas: " + str(continuous))
# Out:
# Categoricas: ['city', 'floor', 'animal', 'furniture']
# Numericas: ['area', 'rooms', 'bathroom', 'parking_spaces', 'hoa', 'rent', 'property_tax', 'fire_insurance']
#  - Discretas: ['rooms', 'bathroom', 'parking_spaces']
#  - Contínuas: ['area', 'hoa', 'rent', 'property_tax', 'fire_insurance']

# %% [markdown]
# # Estudo das variáveis

# %% [markdown]
# ## Categoricas
# - ['city', 'floor', 'animal', 'furniture']

# %%
for var in categorical:
    print(var, ' -> values: ', df[var].unique())
# Out:
# city  -> values:  ['São Paulo' 'Porto Alegre' 'Rio de Janeiro' 'Campinas' 'Belo Horizonte']
# floor  -> values:  ['7' '20' '6' '2' '1' '-' '4' '3' '10' '11' '24' '9' '8' '17' '18' '5'
#  '13' '15' '16' '14' '26' '12' '21' '19' '22' '27' '23' '35' '25' '46'
#  '28' '29' '301' '51' '32']
# animal  -> values:  ['acept' 'not acept']
# furniture  -> values:  ['furnished' 'not furnished']

# %% [markdown]
# ### city
#
# Relação "city" vs "rent"
# - Campinas e Porto Alegre são cidades as quais há mais frequência de alugueis de baixo valor;
# - Equanto São Paulo e Rio de Janeiro há aluguei com valores mais elevados;
# - Belo Horizonte seria um meio termo entre eles;
#
# Conforme abaixo, a feature "city" possui grande relação com o preço do imóvel.
# - Feature Eng: aplicar OneHotEncoded

# %%
pd.DataFrame(df['city'].unique())
# Out:
#                 0
# 0       São Paulo
# 1    Porto Alegre
# 2  Rio de Janeiro
# 3        Campinas
# 4  Belo Horizonte

# %%
g = sns.FacetGrid(df, col='city', height=4, col_wrap=5)
g = g.map(plt.hist, 'rent')

g.set_axis_labels('Rent Amount (R$)', 'Frequency')
g.set_titles('City: {col_name}')

# %% [markdown]
# ### floor
# É difícil relacionar o andar com o preço do imóvel, levando em conta que a maioria dos dados não possui um andar registrado.
# - Portanto, floor será ignorado;

# %%
floor_counts = df["floor"].value_counts()

plt.figure(figsize=(14, 4))
sns.barplot(x=floor_counts.index, y=floor_counts.values)
# Out:
# <Axes: xlabel='floor'>

# %%
g = sns.FacetGrid(df, col='floor', height=4, col_wrap=5)
g = g.map(plt.hist, 'rent')

g.set_axis_labels('Rent Amount (R$)', 'Frequency')
g.set_titles('Floor: {col_name}')

# %% [markdown]
# ### animal
# - Há uma tendência de alugueis mais caros aceitarem animais de estimação;
# - Aplicar OneHotEncoded

# %%
plt.figure(figsize=(4, 6))
sns.boxplot(x=df['animal'], y=df['rent'])
# Out:
# <Axes: xlabel='animal', ylabel='rent'>

# %%
plt.figure(figsize=(15, 6))
sns.violinplot(x ='animal', y ='rent', data = df, hue ='city')
# Out:
# <Axes: xlabel='animal', ylabel='rent'>

# %% [markdown]
# ### furniture
# - Há uma tendência de alugueis mais caros serem de imóveis mobiliados;
# - Aplicar OneHotEncoded

# %%
plt.figure(figsize=(4, 6))
sns.boxplot(x=df['furniture'], y=df['rent'])
# Out:
# <Axes: xlabel='furniture', ylabel='rent'>

# %%
plt.figure(figsize=(15, 6))
sns.violinplot(x ='furniture', y ='rent', data = df, hue ='city')
# Out:
# <Axes: xlabel='furniture', ylabel='rent'>

# %% [markdown]
# ## Numéricas
#  - ['area', 'rooms', 'bathroom', 'parking_spaces', 'hoa', 'rent', 'property_tax', 'fire_insurance']
#    - Discretas: ['rooms', 'bathroom', 'parking_spaces']
#    - Contínuas: ['area', 'hoa', 'rent', 'property_tax', 'fire_insurance']

# %% [markdown]
# Todas as variáveis discretas possuem tendência linear até seus outliers (<5% de registros)

# %%
# Estudo sobre as variáveis discretas
visualize_discrete(df=df, discrete=discrete)

# %% [markdown]
# Todas as variáveis conítuas possuem outliers iqr

# %%
visualize_continuous(df=df, continuous=continuous)

# %%
numerical, categorical, discrete, continuous = distinguish_variables(df)

print("Categoricas: " + str(categorical))
print("Numericas: " + str(numerical))

print(" - Discretas: " + str(discrete))
print(" - Contínuas: " + str(continuous))
# Out:
# Categoricas: ['city', 'floor', 'animal', 'furniture']
# Numericas: ['area', 'rooms', 'bathroom', 'parking_spaces', 'hoa', 'rent', 'property_tax', 'fire_insurance']
#  - Discretas: ['rooms', 'bathroom', 'parking_spaces']
#  - Contínuas: ['area', 'hoa', 'rent', 'property_tax', 'fire_insurance']

# %% [markdown]
# ### Tratamento de Outliers

# %%
visualize_boxplot(df)

# %%
df.describe()
# Out:
#                area         rooms      bathroom  parking_spaces           hoa  \
# count  10334.000000  10334.000000  10334.000000    10334.000000  1.033400e+04
# mean     152.439423      2.539965      2.268725        1.644475  1.091244e+03
# std      545.875595      1.168185      1.414650        1.598527  1.144609e+04
# min       11.000000      1.000000      1.000000        0.000000  0.000000e+00
# 25%       59.000000      2.000000      1.000000        1.000000  1.800000e+02
# 50%       95.000000      3.000000      2.000000        1.000000  5.710000e+02
# 75%      190.000000      3.000000      3.000000        2.000000  1.286750e+03
# max    46335.000000     13.000000     10.000000       12.000000  1.117000e+06
#
#                rent   property_tax  fire_insurance
# count  10334.000000   10334.000000    10334.000000
# mean    3966.296013     376.929263       54.264273
# std     3436.190007    3160.602165       48.164380
# min      450.000000       0.000000        3.000000
# 25%     1598.250000      41.000000       21.000000
# 50%     2750.000000     130.000000       37.000000
# 75%     5000.000000     389.750000       70.000000
# max    45000.000000  313700.000000      677.000000

# %%
# Categoricas: ['city', 'animal', 'furniture']
# Numericas: ['area', 'rooms', 'bathroom', 'parking_spaces', 'floor', 'hoa', 'rent', 'property_tax', 'fire_insurance', 'total']
#  - Discretas: ['rooms', 'bathroom', 'parking_spaces']
#  - Contínuas: ['area', 'floor', 'hoa', 'rent', 'property_tax', 'fire_insurance', 'total']

df_clean = df.drop(["floor"], axis=1)

df_clean = trimmer_skewed_iqr(
    variables=continuous,
    data_frame=df_clean,
)

df_clean = trimmer_normal_quantile(
    variables=discrete,
    data_frame=df_clean,
)

df_clean.info()
# https://www.kaggle.com/datasets/rubenssjr/brasilian-houses-to-rent/code?datasetId=554905&sortBy=voteCount
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8189 entries, 0 to 10691
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   city            8189 non-null   object
#  1   area            8189 non-null   int64
#  2   rooms           8189 non-null   int64
#  3   bathroom        8189 non-null   int64
#  4   parking_spaces  8189 non-null   int64
#  5   animal          8189 non-null   object
#  6   furniture       8189 non-null   object
#  7   hoa             8189 non-null   int64
#  8   rent            8189 non-null   int64
#  9   property_tax    8189 non-null   int64
#  10  fire_insurance  8189 non-null   int64
# dtypes: int64(8), object(3)
# memory usage: 767.7+ KB

# %% [markdown]
# Apos o tratamento dos outliers

# %%
visualize_discrete(df=df_clean, discrete=discrete)

# %%
visualize_continuous(df=df_clean, continuous=continuous)

# %%
visualize_boxplot(df_clean)

# %%
import model as md
from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler

X = df_clean.loc[:, df_clean.columns != "rent"]
Y = df_clean["rent"]
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=1)

# Categoricas: ['city', 'animal', 'furniture']
# Numericas: ['area', 'rooms', 'bathroom', 'parking_spaces', 'hoa', 'property_tax', 'fire_insurance']
#  - Discretas: ['rooms', 'bathroom', 'parking_spaces']
#  - Contínuas: ['area', 'hoa', 'property_tax', 'fire_insurance']
# target 'rent'

ct = make_column_transformer(
    (MinMaxScaler(),  # ou StandardScaler(), dependendo de qual performa melhor
     ['area', 'rooms', 'bathroom', 'parking_spaces', 'hoa', 'property_tax', 'fire_insurance']),
    (OneHotEncoder(categories="auto",
                   # to return k-1 (drop=false to return k dummies)
                   drop="first",
                   sparse_output=False,
                   handle_unknown="error"),
     ['city', 'animal', 'furniture']),
    remainder="passthrough"
)

ct.fit(x_train)
x_train = ct.transform(x_train)
x_test = ct.transform(x_test)

m_one = md.Model(x_train, x_test, y_train, y_test)

m_one.model.summary()
m_one.model.evaluate(m_one.x_train, m_one.y_train)

print("-- MAE (train)")
print(m_one.mae_train())
print("-- MAE")
print(m_one.mae())
print("-- MSE (train)")
print(m_one.mse_train())
print("-- MSE")
print(m_one.mse())
# Out:
# Epoch 1/10000
# 517/517 [==============================] - 1s 901us/step - loss: 2167.1523 - mae: 2167.1523
# Epoch 2/10000
# 517/517 [==============================] - 0s 847us/step - loss: 1022.6115 - mae: 1022.6115
# Epoch 3/10000
# 517/517 [==============================] - 0s 866us/step - loss: 530.4171 - mae: 530.4171
# Epoch 4/10000
# 517/517 [==============================] - 0s 870us/step - loss: 284.5035 - mae: 284.5035
# Epoch 5/10000
# 517/517 [==============================] - 0s 821us/step - loss: 252.8839 - mae: 252.8839
# Epoch 6/10000
# 517/517 [==============================] - 0s 850us/step - loss: 241.4060 - mae: 241.4060
# Epoch 7/10000
# 517/517 [==============================] - 0s 836us/step - loss: 234.9359 - mae: 234.9359
# Epoch 8/10000
# 517/517 [==============================] - 0s 853us/step - loss: 226.1600 - mae: 226.1600
# Epoch 9/10000
# 517/517 [==============================] - 0s 826us/step - loss: 221.7053 - mae: 221.7053
# Epoch 10/10000
# 517/517 [==============================] - 0s 852us/step - loss: 214.0482 - mae: 214.0482
# Epoch 11/10000
# 517/517 [==============================] - 0s 825us/step - loss: 212.6785 - mae: 212.6785
# Epoch 12/10000
# 517/517 [==============================] - 0s 866us/step - loss: 210.2585 - mae: 210.2585
# Epoch 13/10000
# 517/517 [==============================] - 0s 821us/step - loss: 207.7263 - mae: 207.7263
# Epoch 14/10000
# 517/517 [==============================] - 0s 851us/step - loss: 206.6975 - mae: 206.6975
# Epoch 15/10000
# 517/517 [==============================] - 0s 851us/step - loss: 202.9680 - mae: 202.9680
# Epoch 16/10000
# 517/517 [==============================] - 0s 846us/step - loss: 204.6108 - mae: 204.6108
# Epoch 17/10000
# 517/517 [==============================] - 0s 824us/step - loss: 201.7580 - mae: 201.7580
# Epoch 18/10000
# 517/517 [==============================] - 1s 950us/step - loss: 201.3718 - mae: 201.3718
# Epoch 19/10000
# 517/517 [==============================] - 0s 954us/step - loss: 200.6986 - mae: 200.6986
# Epoch 20/10000
# 517/517 [==============================] - 0s 849us/step - loss: 198.3833 - mae: 198.3833
# Epoch 21/10000
# 517/517 [==============================] - 0s 840us/step - loss: 199.5437 - mae: 199.5437
# Epoch 22/10000
# 517/517 [==============================] - 0s 863us/step - loss: 197.3807 - mae: 197.3807
# Epoch 23/10000
# 517/517 [==============================] - 0s 841us/step - loss: 200.5746 - mae: 200.5746
# Epoch 24/10000
# 517/517 [==============================] - 0s 879us/step - loss: 197.6415 - mae: 197.6415
# Epoch 25/10000
# 517/517 [==============================] - 0s 843us/step - loss: 195.9660 - mae: 195.9660
# Epoch 26/10000
# 517/517 [==============================] - 0s 858us/step - loss: 197.8354 - mae: 197.8354
# Epoch 27/10000
# 517/517 [==============================] - 0s 840us/step - loss: 198.4466 - mae: 198.4466
# Epoch 28/10000
# 517/517 [==============================] - 0s 850us/step - loss: 198.2095 - mae: 198.2095
# Epoch 29/10000
# 517/517 [==============================] - 0s 872us/step - loss: 194.7337 - mae: 194.7337
# Epoch 30/10000
# 517/517 [==============================] - 0s 847us/step - loss: 195.2533 - mae: 195.2533
# Epoch 31/10000
# 517/517 [==============================] - 0s 841us/step - loss: 195.3271 - mae: 195.3271
# Epoch 32/10000
# 517/517 [==============================] - 0s 840us/step - loss: 194.3091 - mae: 194.3091
# Epoch 33/10000
# 517/517 [==============================] - 0s 808us/step - loss: 192.0857 - mae: 192.0857
# Epoch 34/10000
# 517/517 [==============================] - 0s 797us/step - loss: 193.8794 - mae: 193.8794
# Epoch 35/10000
# 517/517 [==============================] - 0s 904us/step - loss: 192.5885 - mae: 192.5885
# Epoch 36/10000
# 517/517 [==============================] - 0s 820us/step - loss: 191.6127 - mae: 191.6127
# Epoch 37/10000
# 517/517 [==============================] - 0s 795us/step - loss: 193.1180 - mae: 193.1180
# Epoch 38/10000
# 517/517 [==============================] - 0s 808us/step - loss: 191.0755 - mae: 191.0755
# Epoch 39/10000
# 517/517 [==============================] - 0s 807us/step - loss: 192.7108 - mae: 192.7108
# Epoch 40/10000
# 517/517 [==============================] - 0s 807us/step - loss: 192.4392 - mae: 192.4392
# Epoch 41/10000
# 517/517 [==============================] - 0s 807us/step - loss: 190.6554 - mae: 190.6554
# Epoch 42/10000
# 517/517 [==============================] - 0s 822us/step - loss: 189.7054 - mae: 189.7054
# Epoch 43/10000
# 517/517 [==============================] - 0s 807us/step - loss: 192.1718 - mae: 192.1718
# Epoch 44/10000
# 517/517 [==============================] - 0s 808us/step - loss: 189.8162 - mae: 189.8162
# Epoch 45/10000
# 517/517 [==============================] - 0s 807us/step - loss: 190.0020 - mae: 190.0020
# Epoch 46/10000
# 517/517 [==============================] - 0s 807us/step - loss: 187.3370 - mae: 187.3370
# Epoch 47/10000
# 517/517 [==============================] - 0s 808us/step - loss: 186.2536 - mae: 186.2536
# Epoch 48/10000
# 517/517 [==============================] - 0s 808us/step - loss: 186.4220 - mae: 186.4220
# Epoch 49/10000
# 517/517 [==============================] - 0s 807us/step - loss: 187.4876 - mae: 187.4876
# Epoch 50/10000
# 517/517 [==============================] - 0s 905us/step - loss: 185.0408 - mae: 185.0408
# Epoch 51/10000
# 517/517 [==============================] - 0s 807us/step - loss: 183.5629 - mae: 183.5629
# Epoch 52/10000
# 517/517 [==============================] - 0s 837us/step - loss: 184.7673 - mae: 184.7673
# Epoch 53/10000
# 517/517 [==============================] - 0s 805us/step - loss: 181.6346 - mae: 181.6346
# Epoch 54/10000
# 517/517 [==============================] - 0s 807us/step - loss: 183.4351 - mae: 183.4351
# Epoch 55/10000
# 517/517 [==============================] - 0s 807us/step - loss: 180.2442 - mae: 180.2442
# Epoch 56/10000
# 517/517 [==============================] - 0s 808us/step - loss: 180.4930 - mae: 180.4930
# Epoch 57/10000
# 517/517 [==============================] - 0s 840us/step - loss: 179.2277 - mae: 179.2277
# Epoch 58/10000
# 517/517 [==============================] - 0s 808us/step - loss: 175.6913 - mae: 175.6913
# Epoch 59/10000
# 517/517 [==============================] - 0s 807us/step - loss: 176.6761 - mae: 176.6761
# Epoch 60/10000
# 517/517 [==============================] - 0s 872us/step - loss: 175.1832 - mae: 175.1832
# Epoch 61/10000
# 517/517 [==============================] - 0s 808us/step - loss: 172.3380 - mae: 172.3380
# Epoch 62/10000
# 517/517 [==============================] - 0s 808us/step - loss: 169.1059 - mae: 169.1059
# Epoch 63/10000
# 517/517 [==============================] - 0s 807us/step - loss: 166.3775 - mae: 166.3775
# Epoch 64/10000
# 517/517 [==============================] - 0s 938us/step - loss: 160.5405 - mae: 160.5405
# Epoch 65/10000
# 517/517 [==============================] - 0s 839us/step - loss: 156.1320 - mae: 156.1320
# Epoch 66/10000
# 517/517 [==============================] - 0s 808us/step - loss: 152.0018 - mae: 152.0018
# Epoch 67/10000
# 517/517 [==============================] - 0s 808us/step - loss: 147.1624 - mae: 147.1624
# Epoch 68/10000
# 517/517 [==============================] - 0s 839us/step - loss: 141.5444 - mae: 141.5444
# Epoch 69/10000
# 517/517 [==============================] - 0s 808us/step - loss: 134.2293 - mae: 134.2293
# Epoch 70/10000
# 517/517 [==============================] - 0s 808us/step - loss: 130.3909 - mae: 130.3909
# Epoch 71/10000
# 517/517 [==============================] - 0s 809us/step - loss: 124.4580 - mae: 124.4580
# Epoch 72/10000
# 517/517 [==============================] - 0s 839us/step - loss: 119.8968 - mae: 119.8968
# Epoch 73/10000
# 517/517 [==============================] - 0s 807us/step - loss: 116.7470 - mae: 116.7470
# Epoch 74/10000
# 517/517 [==============================] - 0s 938us/step - loss: 116.6145 - mae: 116.6145
# Epoch 75/10000
# 517/517 [==============================] - 0s 839us/step - loss: 112.1690 - mae: 112.1690
# Epoch 76/10000
# 517/517 [==============================] - 0s 807us/step - loss: 109.8070 - mae: 109.8070
# Epoch 77/10000
# 517/517 [==============================] - 0s 808us/step - loss: 109.9855 - mae: 109.9855
# Epoch 78/10000
# 517/517 [==============================] - 0s 807us/step - loss: 105.5088 - mae: 105.5088
# Epoch 79/10000
# 517/517 [==============================] - 0s 808us/step - loss: 105.4491 - mae: 105.4491
# Epoch 80/10000
# 517/517 [==============================] - 0s 840us/step - loss: 101.1944 - mae: 101.1944
# Epoch 81/10000
# 517/517 [==============================] - 0s 807us/step - loss: 101.0256 - mae: 101.0256
# Epoch 82/10000
# 517/517 [==============================] - 0s 840us/step - loss: 97.6005 - mae: 97.6005
# Epoch 83/10000
# 517/517 [==============================] - 0s 841us/step - loss: 97.6440 - mae: 97.6440
# Epoch 84/10000
# 517/517 [==============================] - 0s 846us/step - loss: 96.3940 - mae: 96.3940
# Epoch 85/10000
# 517/517 [==============================] - 0s 793us/step - loss: 95.1690 - mae: 95.1690
# Epoch 86/10000
# 517/517 [==============================] - 1s 940us/step - loss: 92.0902 - mae: 92.0902
# Epoch 87/10000
# 517/517 [==============================] - 0s 874us/step - loss: 93.0741 - mae: 93.0741
# Epoch 88/10000
# 517/517 [==============================] - 0s 805us/step - loss: 91.2077 - mae: 91.2077
# Epoch 89/10000
# 517/517 [==============================] - 0s 840us/step - loss: 89.5664 - mae: 89.5664
# Epoch 90/10000
# 517/517 [==============================] - 0s 832us/step - loss: 89.6263 - mae: 89.6263
# Epoch 91/10000
# 517/517 [==============================] - 0s 814us/step - loss: 89.1529 - mae: 89.1529
# Epoch 92/10000
# 517/517 [==============================] - 0s 801us/step - loss: 88.8360 - mae: 88.8360
# Epoch 93/10000
# 517/517 [==============================] - 0s 807us/step - loss: 88.3935 - mae: 88.3935
# Epoch 94/10000
# 517/517 [==============================] - 0s 840us/step - loss: 86.6645 - mae: 86.6645
# Epoch 95/10000
# 517/517 [==============================] - 0s 807us/step - loss: 86.1596 - mae: 86.1596
# Epoch 96/10000
# 517/517 [==============================] - 0s 818us/step - loss: 85.4728 - mae: 85.4728
# Epoch 97/10000
# 517/517 [==============================] - 0s 809us/step - loss: 85.3357 - mae: 85.3357
# Epoch 98/10000
# 517/517 [==============================] - 0s 808us/step - loss: 83.9974 - mae: 83.9974
# Epoch 99/10000
# 517/517 [==============================] - 0s 807us/step - loss: 83.5611 - mae: 83.5611
# Epoch 100/10000
# 517/517 [==============================] - 0s 969us/step - loss: 83.4354 - mae: 83.4354
# Epoch 101/10000
# 517/517 [==============================] - 0s 808us/step - loss: 83.1089 - mae: 83.1089
# Epoch 102/10000
# 517/517 [==============================] - 0s 811us/step - loss: 82.9786 - mae: 82.9786
# Epoch 103/10000
# 517/517 [==============================] - 0s 840us/step - loss: 83.1000 - mae: 83.1000
# Epoch 104/10000
# 517/517 [==============================] - 0s 840us/step - loss: 82.5324 - mae: 82.5324
# Epoch 105/10000
# 517/517 [==============================] - 0s 840us/step - loss: 82.3922 - mae: 82.3922
# Epoch 106/10000
# 517/517 [==============================] - 0s 808us/step - loss: 80.8602 - mae: 80.8602
# Epoch 107/10000
# 517/517 [==============================] - 0s 807us/step - loss: 83.3654 - mae: 83.3654
# Epoch 108/10000
# 517/517 [==============================] - 0s 811us/step - loss: 81.6413 - mae: 81.6413
# Epoch 109/10000
# 517/517 [==============================] - 0s 810us/step - loss: 80.3963 - mae: 80.3963
# Epoch 110/10000
# 517/517 [==============================] - 0s 804us/step - loss: 81.2908 - mae: 81.2908
# Epoch 111/10000
# 517/517 [==============================] - 0s 807us/step - loss: 80.3558 - mae: 80.3558
# Epoch 112/10000
# 517/517 [==============================] - 0s 937us/step - loss: 80.8634 - mae: 80.8634
# Epoch 113/10000
# 517/517 [==============================] - 0s 840us/step - loss: 80.3153 - mae: 80.3153
# Epoch 114/10000
# 517/517 [==============================] - 0s 838us/step - loss: 80.2665 - mae: 80.2665
# Epoch 115/10000
# 517/517 [==============================] - 0s 833us/step - loss: 81.5713 - mae: 81.5713
# Epoch 116/10000
# 517/517 [==============================] - 0s 775us/step - loss: 79.4076 - mae: 79.4076
# Epoch 117/10000
# 517/517 [==============================] - 0s 820us/step - loss: 81.0128 - mae: 81.0128
# Epoch 118/10000
# 517/517 [==============================] - 0s 821us/step - loss: 79.5684 - mae: 79.5684
# Epoch 119/10000
# 517/517 [==============================] - 0s 808us/step - loss: 79.1875 - mae: 79.1875
# Epoch 120/10000
# 517/517 [==============================] - 0s 807us/step - loss: 80.2930 - mae: 80.2930
# Epoch 121/10000
# 517/517 [==============================] - 0s 808us/step - loss: 81.4030 - mae: 81.4030
# Epoch 122/10000
# 517/517 [==============================] - 0s 839us/step - loss: 79.9781 - mae: 79.9781
# Epoch 123/10000
# 517/517 [==============================] - 0s 840us/step - loss: 80.2888 - mae: 80.2888
# Epoch 124/10000
# 517/517 [==============================] - 0s 937us/step - loss: 78.8996 - mae: 78.8996
# Epoch 125/10000
# 517/517 [==============================] - 0s 840us/step - loss: 79.4754 - mae: 79.4754
# Epoch 126/10000
# 517/517 [==============================] - 0s 808us/step - loss: 77.7633 - mae: 77.7633
# Epoch 127/10000
# 517/517 [==============================] - 0s 842us/step - loss: 79.6055 - mae: 79.6055
# Epoch 128/10000
# 517/517 [==============================] - 0s 807us/step - loss: 80.1188 - mae: 80.1188
# Epoch 129/10000
# 517/517 [==============================] - 0s 839us/step - loss: 77.0113 - mae: 77.0113
# Epoch 130/10000
# 517/517 [==============================] - 0s 807us/step - loss: 78.9326 - mae: 78.9326
# Epoch 131/10000
# 517/517 [==============================] - 0s 839us/step - loss: 80.0467 - mae: 80.0467
# Epoch 132/10000
# 517/517 [==============================] - 0s 808us/step - loss: 76.9646 - mae: 76.9646
# Epoch 133/10000
# 517/517 [==============================] - 0s 807us/step - loss: 77.5622 - mae: 77.5622
# Epoch 134/10000
# 517/517 [==============================] - 0s 840us/step - loss: 77.6930 - mae: 77.6930
# Epoch 135/10000
# 517/517 [==============================] - 0s 838us/step - loss: 77.6471 - mae: 77.6471
# Epoch 136/10000
# 517/517 [==============================] - 0s 934us/step - loss: 79.8294 - mae: 79.8294
# Epoch 137/10000
# 517/517 [==============================] - 0s 814us/step - loss: 77.8796 - mae: 77.8796
# 259/259 [==============================] - 0s 600us/step
# 65/65 [==============================] - 0s 522us/step
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 150)               2100
#
#  dense_13 (Dense)            (None, 100)               15100
#
#  dense_14 (Dense)            (None, 50)                5050
#
#  dense_15 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 22,301
# Trainable params: 22,301
# Non-trainable params: 0
# _________________________________________________________________
# 259/259 [==============================] - 0s 710us/step - loss: 76.3386 - mae: 76.3386
# -- MAE (train)
# tf.Tensor(76.338615, shape=(), dtype=float32)
# -- MAE
# tf.Tensor(94.559166, shape=(), dtype=float32)
# -- MSE (train)
# tf.Tensor(88065.77, shape=(), dtype=float32)
# -- MSE
# tf.Tensor(577053.94, shape=(), dtype=float32)
